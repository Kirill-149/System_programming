# %% [markdown]
# # Задания к зачету

# %% [markdown]
# 1. Разработать программу на языке ассемблере, которая принимает параметром командной строки файл со случайными числами и сохраняет их в отсортированном порядке во второй файл, имя этого файла пользователь вводит в режиме диалога с программой.
# 2. Имеется доска P, расположенная по середине комнаты, на которой записано число 0. Два человека A1  и A2 стоят возле нее. В разных концах комнаты расположены две лампочки: L1 и L2. Каждая лампочка в случайный момент времени вспыхивает. Человек A1 наблюдает за лампочкой L1, A2 - за лампочкой L2. Если лампочка загорается, то ответственный за нее человек запоминает число, записанное на доске и отправляется выключать лампочку. Выключив лампочку, человек возвращается и записывает на доске число, которое он запомнил плюс один. Задание: добиться, чтобы число на доске отражало суммарное количество включений двух лампочек. С использованием семафоров и тредов разработать программу на языке ассемблере, решающую данную задачу.
# 3. На языке shell реализовать три скрипта: 1. печатает содержимое заданного каталога; 2. находит наименьшее из трех чисел; 3. сохраняет в файл список всех процессов. На языке ассемблере реализовать интерпретатор, ожидающий заданную команду (имя скрипта) и запускающего его.
# 4. С использованием сокетов реализовать сервер на языке ассемблере, который принимает от клиента несколько чисел (количество заранее неопределено, конец ввода обозначается передачей на сервер специального символа). По окончанию ввода сервер возвращает клиенту среднее значение введенных чисел.
# 5. С использованием сокетов реализовать сервер на языке ассемблере, который принимает от клиента несколько чисел (количество заранее неопределено, конец ввода обозначается передачей на сервер специального символа). По окончанию ввода сервер возвращает клиенту медианное значение введенных чисел.
# 6. С использованием сокетов реализовать сервер на языке ассемблере, который принимает от клиента несколько чисел (количество заранее неопределено, конец ввода обозначается передачей на сервер специального символа). По окончанию ввода сервер возвращает клиенту количество чисел палиндромов (читаются одинаково слева направо и справа налево).
# 7. Пусть требуется найти значение $x_0$, при котором для заданной функции $f(x)$ получится $f(x_0)=0$. Одним из методов решения подобной задачи является метод последовательных приближений. Суть метода состоит в следующем. От уравнения $f(x)=0$ переходят к эквивалентному уравнению $$\varphi(x)=x.$$ Далее, задавшись начальным приближением $x=x_1$, вычисляют: $$x_2=\varphi(x_1),$$ считая полученное значение $x_2$ вторым приближением. Повторяя подобные преобразования $n$ раз, находят $n$-е приближение корня уравнения $f(x)$: $$x_n=\varphi(x_{n-1}).$$ Используя данный метод, найти корень уравнения $$2x+\cos(x)-\ln(x)=0,$$ разработав программу на языке ассемблере (в программе использовать математический сопроцессор).

# %%
import random as rd

Variant = 4
rd.seed(Variant+2026)
rd.sample({1,2,3,4,5,6,7}, 2)
# Out:
# <ipython-input-2-0615b0393d48>:5: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   rd.sample({1,2,3,4,5,6,7}, 2)
# [4, 5]
